# %%
import pandas as pd

df = pd.read_csv("Traveling_Expenses_All_2026.csv")

print(df.head())
print(df.info())
# Out:
#   Expense_ID       Payee_Name Competent_Person_Engineer  \
# 0    TRV1001  Shivam Passwala          Shivani Passwala
# 1    TRV1002  Shivam Passwala          Shivani Passwala
# 2    TRV1003      Karan Desai               Karan Desai
# 3    TRV1004  Shivam Passwala          Shivani Passwala
# 4    TRV1005  Shivam Passwala          Shivani Passwala
#
#                           Purpose                             Work_Done  \
# 0            Equipment Inspection  NDT & Inspection of Pressure vessels
# 1                  NDT Inspection            Pressure Vessel Inspection
# 2                  NDT Inspection               Visual & NDT Inspection
# 3  Inspection of Pressure vessels            Pressure Vessel Inspection
# 4                  NDT Inspection               Visual & NDT Inspection
#
#              Site_Name               Client      Site_City Travel_Start_Date  \
# 0   Gujarat Pneumatics  Gujarat Gas Limited         Sanand        25/05/2026
# 1   Gujarat Pneumatics  Gujarat Gas Limited         Limbdi        26/04/2026
# 2  NDT Inspection Site      Larsen & Toubro  Surendranagar        08/01/2026
# 3   Gujarat Pneumatics  Gujarat Gas Limited         Limbdi        18/07/2026
# 4  NDT Inspection Site      Larsen & Toubro  Surendranagar        22/11/2026
#
#   Travel_End_Date  ...  Lodging_Boarding_Expense  Local_Conveyance_Expense  \
# 0      26/05/2026  ...                      2343                      1708
# 1      27/04/2026  ...                      6131                       254
# 2      14/01/2026  ...                      2507                      1629
# 3      18/07/2026  ...                      4017                      1436
# 4      26/11/2026  ...                      4162                      1382
#
#    Petrol_Diesel_Expense  NDT_Charges  Other_Expense  Advance_Payment  \
# 0                      0        12000            500            10278
# 1                   1200         3500            500            10095
# 2                   1000         5000            100             7566
# 3                    800            0            250             8361
# 4                    500        12000              0            11028
#
#    Balance_Amount  Total_Amount     Month  Year
# 0            7430         17708       May  2026
# 1            3224         13319     April  2026
# 2            5020         12586   January  2026
# 3            -423          7938      July  2026
# 4            9529         20557  November  2026
#
# [5 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Expense_ID                 100 non-null    object
#  1   Payee_Name                 100 non-null    object
#  2   Competent_Person_Engineer  100 non-null    object
#  3   Purpose                    100 non-null    object
#  4   Work_Done                  100 non-null    object
#  5   Site_Name                  100 non-null    object
#  6   Client                     100 non-null    object
#  7   Site_City                  100 non-null    object
#  8   Travel_Start_Date          100 non-null    object
#  9   Travel_End_Date            100 non-null    object
#  10  Travel_Days                100 non-null    int64
#  11  Food_Expense               100 non-null    int64
#  12  Lodging_Boarding_Expense   100 non-null    int64
#  13  Local_Conveyance_Expense   100 non-null    int64
#  14  Petrol_Diesel_Expense      100 non-null    int64
#  15  NDT_Charges                100 non-null    int64
#  16  Other_Expense              100 non-null    int64
#  17  Advance_Payment            100 non-null    int64
#  18  Balance_Amount             100 non-null    int64
#  19  Total_Amount               100 non-null    int64
#  20  Month                      100 non-null    object
#  21  Year                       100 non-null    int64
# dtypes: int64(11), object(11)
# memory usage: 17.3+ KB
# None

# %%
df["Total_Amount"].sum()
# Out:
# np.int64(1363488)

# %%
df.groupby("Payee_Name")["Total_Amount"].sum()
# Out:
# Payee_Name
# Amit Shah          245133
# Karan Desai        257979
# Rahul Patel        161813
# Shivam Passwala    385160
# Vishal Joshi       313403
# Name: Total_Amount, dtype: int64

# %%
df.groupby("Client")["Total_Amount"].sum()
# Out:
# Client
# Adani Group            180295
# Essar                   96943
# Gujarat Alkalies       156400
# Gujarat Gas Limited    383158
# Larsen & Toubro        188968
# ONGC                   227014
# Reliance Industries    130710
# Name: Total_Amount, dtype: int64

# %%
df.groupby("Site_City")["Total_Amount"].sum()
# Out:
# Site_City
# Bhuj              96943
# Hazira           227014
# Jamnagar         130710
# Limbdi           169310
# Mundra           180295
# Sanand           213848
# Surendranagar    188968
# Vadodara         156400
# Name: Total_Amount, dtype: int64

# %%
df[[
    "Food_Expense",
    "Lodging_Boarding_Expense",
    "Local_Conveyance_Expense",
    "Petrol_Diesel_Expense",
    "NDT_Charges"
]].sum()
# Out:
# Food_Expense                160595
# Lodging_Boarding_Expense    434526
# Local_Conveyance_Expense     98917
# Petrol_Diesel_Expense       103400
# NDT_Charges                 546500
# dtype: int64

# %%
df.loc[df["Total_Amount"].idxmax()]
# Out:
# Expense_ID                                          TRV1078
# Payee_Name                                     Vishal Joshi
# Competent_Person_Engineer                      Vishal Joshi
# Purpose                      Inspection of Pressure vessels
# Work_Done                                    NDT Inspection
# Site_Name                                Gujarat Pneumatics
# Client                                  Gujarat Gas Limited
# Site_City                                            Sanand
# Travel_Start_Date                                11/04/2026
# Travel_End_Date                                  15/04/2026
# Travel_Days                                               5
# Food_Expense                                           1440
# Lodging_Boarding_Expense                               6300
# Local_Conveyance_Expense                               1749
# Petrol_Diesel_Expense                                  1000
# NDT_Charges                                           12000
# Other_Expense                                           250
# Advance_Payment                                       23820
# Balance_Amount                                        -1081
# Total_Amount                                          22739
# Month                                                 April
# Year                                                   2026
# Name: 77, dtype: object

# %%
monthly_expense = (
    df.groupby("Month")["Total_Amount"]
    .sum()
)

monthly_expense
# Out:
# Month
# April        147227
# August       160223
# February      95964
# January       30627
# July         132576
# June         262061
# March        139264
# May          206802
# November      93552
# October       56247
# September     38945
# Name: Total_Amount, dtype: int64

# %%
highest_month = monthly_expense.idxmax()
highest_amount = monthly_expense.max()

lowest_month = monthly_expense.idxmin()
lowest_amount = monthly_expense.min()

print("Highest Expense Month:", highest_month)
print("Highest Expense Amount:", highest_amount)

print("Lowest Expense Month:", lowest_month)
print("Lowest Expense Amount:", lowest_amount)
# Out:
# Highest Expense Month: June
# Highest Expense Amount: 262061
# Lowest Expense Month: January
# Lowest Expense Amount: 30627

# %%
df["Expense_Per_Day"] = df["Total_Amount"] / df["Travel_Days"]

print("Average Expense Per Travel Day:", round(df["Expense_Per_Day"].mean(), 2))
print("Highest Expense Per Day:", round(df["Expense_Per_Day"].max(), 2))
print("Lowest Expense Per Day:", round(df["Expense_Per_Day"].min(), 2))
# Out:
# Average Expense Per Travel Day: 4828.03
# Highest Expense Per Day: 18163.0
# Lowest Expense Per Day: 910.0

# %%
print("Total Advance Payment:", df["Advance_Payment"].sum())
print("Total Travel Expense:", df["Total_Amount"].sum())
print("Total Balance Amount:", df["Balance_Amount"].sum())

print("\nAverage Advance Payment:", round(df["Advance_Payment"].mean(), 2))
print("Average Travel Expense:", round(df["Total_Amount"].mean(), 2))
print("Average Balance Amount:", round(df["Balance_Amount"].mean(), 2))
# Out:
# Total Advance Payment: 1110324
# Total Travel Expense: 1363488
# Total Balance Amount: 253164
#
# Average Advance Payment: 11103.24
# Average Travel Expense: 13634.88
# Average Balance Amount: 2531.64

# %%
positive_balance = (df["Balance_Amount"] > 0).sum()
negative_balance = (df["Balance_Amount"] < 0).sum()
zero_balance = (df["Balance_Amount"] == 0).sum()

print("Positive Balance Records:", positive_balance)
print("Negative Balance Records:", negative_balance)
print("Zero Balance Records:", zero_balance)
# Out:
# Positive Balance Records: 80
# Negative Balance Records: 20
# Zero Balance Records: 0

# %%
client_avg_expense = (
    df.groupby("Client")["Total_Amount"]
      .mean()
      .sort_values(ascending=False)
      .round(2)
)

print(client_avg_expense)
# Out:
# Client
# Larsen & Toubro        14536.00
# ONGC                   14188.38
# Adani Group            13868.85
# Gujarat Gas Limited    13684.21
# Reliance Industries    13071.00
# Gujarat Alkalies       13033.33
# Essar                  12117.88
# Name: Total_Amount, dtype: float64

# %%
top_10_trips = (
    df[["Expense_ID", "Payee_Name", "Client", "Site_City", "Travel_Days", "Total_Amount"]]
    .sort_values("Total_Amount", ascending=False)
    .head(10)
)

print(top_10_trips)
# Out:
#    Expense_ID       Payee_Name               Client      Site_City  \
# 77    TRV1078     Vishal Joshi  Gujarat Gas Limited         Sanand
# 83    TRV1084     Vishal Joshi  Gujarat Gas Limited         Sanand
# 61    TRV1062  Shivam Passwala  Gujarat Gas Limited         Limbdi
# 4     TRV1005  Shivam Passwala      Larsen & Toubro  Surendranagar
# 39    TRV1040      Karan Desai  Gujarat Gas Limited         Sanand
# 91    TRV1092     Vishal Joshi  Gujarat Gas Limited         Limbdi
# 47    TRV1048      Rahul Patel                 ONGC         Hazira
# 40    TRV1041      Rahul Patel     Gujarat Alkalies       Vadodara
# 57    TRV1058      Rahul Patel                 ONGC         Hazira
# 89    TRV1090     Vishal Joshi  Reliance Industries       Jamnagar
#
#     Travel_Days  Total_Amount
# 77            5         22739
# 83            6         22625
# 61            2         22393
# 4             5         20557
# 39            3         20538
# 91            4         20288
# 47            7         20283
# 40            6         19652
# 57            6         19499
# 89            4         19227

# %%
expense_categories = [
    "Food_Expense",
    "Lodging_Boarding_Expense",
    "Local_Conveyance_Expense",
    "Petrol_Diesel_Expense",
    "NDT_Charges",
    "Other_Expense"
]

category_percentage = (
    df[expense_categories].sum() / df[expense_categories].sum().sum() * 100
).round(2)

print(category_percentage.sort_values(ascending=False))
# Out:
# NDT_Charges                 40.08
# Lodging_Boarding_Expense    31.87
# Food_Expense                11.78
# Petrol_Diesel_Expense        7.58
# Local_Conveyance_Expense     7.25
# Other_Expense                1.43
# dtype: float64

# %%
travel_days_analysis = (
    df.groupby("Travel_Days")
      .agg(
          Total_Expense=("Total_Amount", "sum"),
          Average_Expense=("Total_Amount", "mean"),
          Number_of_Trips=("Expense_ID", "count")
      )
      .sort_index()
      .round(2)
)

print(travel_days_analysis)
# Out:
#              Total_Expense  Average_Expense  Number_of_Trips
# Travel_Days
# 1                   140738         12794.36               11
# 2                   261572         12455.81               21
# 3                   202783         15598.69               13
# 4                   200462         14318.71               14
# 5                   116290         14536.25                8
# 6                   303227         13183.78               23
# 7                   138416         13841.60               10

# %%
work_analysis = (
    df.groupby("Work_Done")
      .agg(
          Total_Expense=("Total_Amount", "sum"),
          Average_Expense=("Total_Amount", "mean"),
          Number_of_Trips=("Expense_ID", "count")
      )
      .sort_values("Total_Expense", ascending=False)
      .round(2)
)

print(work_analysis)
# Out:
#                                       Total_Expense  Average_Expense  \
# Work_Done
# NDT Inspection                               425614         14676.34
# Pressure Vessel Inspection                   354361         13124.48
# Visual & NDT Inspection                      321964         13415.17
# NDT & Inspection of Pressure vessels         261549         13077.45
#
#                                       Number_of_Trips
# Work_Done
# NDT Inspection                                     29
# Pressure Vessel Inspection                         27
# Visual & NDT Inspection                            24
# NDT & Inspection of Pressure vessels               20

# %%
employee_work_analysis = (
    df.groupby(["Payee_Name", "Work_Done"])["Total_Amount"]
      .agg(["sum", "mean", "count"])
      .round(2)
      .sort_values("sum", ascending=False)
)

print(employee_work_analysis)
# Out:
#                                                          sum      mean  count
# Payee_Name      Work_Done
# Vishal Joshi    NDT Inspection                        125554  17936.29      7
# Shivam Passwala Pressure Vessel Inspection            109096  13637.00      8
# Karan Desai     Pressure Vessel Inspection            106536  13317.00      8
# Shivam Passwala Visual & NDT Inspection               103432  14776.00      7
# Amit Shah       NDT Inspection                         99336  12417.00      8
# Shivam Passwala NDT Inspection                         97462  16243.67      6
# Vishal Joshi    NDT & Inspection of Pressure vessels   75779  12629.83      6
# Shivam Passwala NDT & Inspection of Pressure vessels   75170  15034.00      5
# Amit Shah       Visual & NDT Inspection                63531  10588.50      6
#                 Pressure Vessel Inspection             59979  14994.75      4
# Vishal Joshi    Pressure Vessel Inspection             56857  11371.40      5
#                 Visual & NDT Inspection                55213  13803.25      4
# Karan Desai     NDT Inspection                         54829  10965.80      5
#                 Visual & NDT Inspection                50599  12649.75      4
# Rahul Patel     Visual & NDT Inspection                49189  16396.33      3
#                 NDT Inspection                         48433  16144.33      3
# Karan Desai     NDT & Inspection of Pressure vessels   46015  11503.75      4
# Rahul Patel     NDT & Inspection of Pressure vessels   42298  14099.33      3
# Amit Shah       NDT & Inspection of Pressure vessels   22287  11143.50      2
# Rahul Patel     Pressure Vessel Inspection             21893  10946.50      2

# %%
work_daily_analysis = (
    df.groupby("Work_Done")
      .agg(
          Total_Expense=("Total_Amount", "sum"),
          Total_Travel_Days=("Travel_Days", "sum"),
          Average_Expense_Per_Day=("Total_Amount", "mean")
      )
)

work_daily_analysis["Expense_Per_Travel_Day"] = (
    work_daily_analysis["Total_Expense"] /
    work_daily_analysis["Total_Travel_Days"]
).round(2)

work_daily_analysis = work_daily_analysis.sort_values(
    "Expense_Per_Travel_Day",
    ascending=False
)

print(work_daily_analysis.round(2))
# Out:
#                                       Total_Expense  Total_Travel_Days  \
# Work_Done
# NDT & Inspection of Pressure vessels         261549                 58
# Pressure Vessel Inspection                   354361                 97
# Visual & NDT Inspection                      321964                 98
# NDT Inspection                               425614                143
#
#                                       Average_Expense_Per_Day  \
# Work_Done
# NDT & Inspection of Pressure vessels                 13077.45
# Pressure Vessel Inspection                           13124.48
# Visual & NDT Inspection                              13415.17
# NDT Inspection                                       14676.34
#
#                                       Expense_Per_Travel_Day
# Work_Done
# NDT & Inspection of Pressure vessels                 4509.47
# Pressure Vessel Inspection                           3653.21
# Visual & NDT Inspection                              3285.35
# NDT Inspection                                       2976.32

# %%
employee_efficiency = (
    df.groupby("Payee_Name")
      .agg(
          Total_Expense=("Total_Amount", "sum"),
          Total_Travel_Days=("Travel_Days", "sum"),
          Number_of_Trips=("Expense_ID", "count")
      )
)

employee_efficiency["Expense_Per_Travel_Day"] = (
    employee_efficiency["Total_Expense"] /
    employee_efficiency["Total_Travel_Days"]
).round(2)

employee_efficiency = employee_efficiency.sort_values(
    "Expense_Per_Travel_Day",
    ascending=False
)

print(employee_efficiency.round(2))
# Out:
#                  Total_Expense  Total_Travel_Days  Number_of_Trips  \
# Payee_Name
# Vishal Joshi            313403                 73               22
# Shivam Passwala         385160                101               26
# Rahul Patel             161813                 46               11
# Karan Desai             257979                 80               21
# Amit Shah               245133                 96               20
#
#                  Expense_Per_Travel_Day
# Payee_Name
# Vishal Joshi                    4293.19
# Shivam Passwala                 3813.47
# Rahul Patel                     3517.67
# Karan Desai                     3224.74
# Amit Shah                       2553.47

# %%
site_efficiency = (
    df.groupby("Site_City")
      .agg(
          Total_Expense=("Total_Amount", "sum"),
          Total_Travel_Days=("Travel_Days", "sum"),
          Number_of_Trips=("Expense_ID", "count")
      )
)

site_efficiency["Expense_Per_Travel_Day"] = (
    site_efficiency["Total_Expense"] /
    site_efficiency["Total_Travel_Days"]
).round(2)

site_efficiency = site_efficiency.sort_values(
    "Expense_Per_Travel_Day",
    ascending=False
)

print(site_efficiency)
# Out:
#                Total_Expense  Total_Travel_Days  Number_of_Trips  \
# Site_City
# Mundra                180295                 42               13
# Limbdi                169310                 42               12
# Jamnagar              130710                 33               10
# Surendranagar         188968                 49               13
# Sanand                213848                 62               16
# Hazira                227014                 78               16
# Vadodara              156400                 55               12
# Bhuj                   96943                 35                8
#
#                Expense_Per_Travel_Day
# Site_City
# Mundra                        4292.74
# Limbdi                        4031.19
# Jamnagar                      3960.91
# Surendranagar                 3856.49
# Sanand                        3449.16
# Hazira                        2910.44
# Vadodara                      2843.64
# Bhuj                          2769.80

# %%
site_category_expense = df.groupby("Site_City")[
    [
        "Food_Expense",
        "Lodging_Boarding_Expense",
        "Local_Conveyance_Expense",
        "Petrol_Diesel_Expense",
        "NDT_Charges",
        "Other_Expense"
    ]
].sum()

print(site_category_expense)
# Out:
#                Food_Expense  Lodging_Boarding_Expense  \
# Site_City
# Bhuj                  14854                     32717
# Hazira                25593                     64540
# Jamnagar              16346                     46222
# Limbdi                17956                     54705
# Mundra                20768                     56021
# Sanand                22823                     68621
# Surendranagar         22989                     55141
# Vadodara              19266                     56559
#
#                Local_Conveyance_Expense  Petrol_Diesel_Expense  NDT_Charges  \
# Site_City
# Bhuj                               5572                  11500        31500
# Hazira                            13981                  13100       106500
# Jamnagar                           8142                   8300        49000
# Limbdi                            11399                  10900        72000
# Mundra                            15006                  17500        68000
# Sanand                            19454                  15000        85000
# Surendranagar                     13388                  13800        81500
# Vadodara                          11975                  13300        53000
#
#                Other_Expense
# Site_City
# Bhuj                     800
# Hazira                  3300
# Jamnagar                2700
# Limbdi                  2350
# Mundra                  3000
# Sanand                  2950
# Surendranagar           2150
# Vadodara                2300

# %%
site_cost_efficiency = (
    df.groupby("Site_City")
      .agg(
          Total_Expense=("Total_Amount", "sum"),
          Total_Travel_Days=("Travel_Days", "sum"),
          Number_of_Trips=("Expense_ID", "count"),
          Total_Lodging=("Lodging_Boarding_Expense", "sum"),
          Total_NDT=("NDT_Charges", "sum")
      )
)

site_cost_efficiency["Expense_Per_Day"] = (
    site_cost_efficiency["Total_Expense"] /
    site_cost_efficiency["Total_Travel_Days"]
).round(2)

site_cost_efficiency["Expense_Per_Trip"] = (
    site_cost_efficiency["Total_Expense"] /
    site_cost_efficiency["Number_of_Trips"]
).round(2)

print(site_cost_efficiency.sort_values(
    "Expense_Per_Day",
    ascending=False
))
# Out:
#                Total_Expense  Total_Travel_Days  Number_of_Trips  \
# Site_City
# Mundra                180295                 42               13
# Limbdi                169310                 42               12
# Jamnagar              130710                 33               10
# Surendranagar         188968                 49               13
# Sanand                213848                 62               16
# Hazira                227014                 78               16
# Vadodara              156400                 55               12
# Bhuj                   96943                 35                8
#
#                Total_Lodging  Total_NDT  Expense_Per_Day  Expense_Per_Trip
# Site_City
# Mundra                 56021      68000          4292.74          13868.85
# Limbdi                 54705      72000          4031.19          14109.17
# Jamnagar               46222      49000          3960.91          13071.00
# Surendranagar          55141      81500          3856.49          14536.00
# Sanand                 68621      85000          3449.16          13365.50
# Hazira                 64540     106500          2910.44          14188.38
# Vadodara               56559      53000          2843.64          13033.33
# Bhuj                   32717      31500          2769.80          12117.88

# %%
overall_daily_cost = df["Total_Amount"].sum() / df["Travel_Days"].sum()

print("Overall Average Expense Per Travel Day:", round(overall_daily_cost, 2))

site_cost_efficiency["Extra_Cost_Per_Day"] = (
    site_cost_efficiency["Expense_Per_Day"] - overall_daily_cost
).round(2)

site_cost_efficiency["Potential_Extra_Cost"] = (
    site_cost_efficiency["Extra_Cost_Per_Day"] *
    site_cost_efficiency["Total_Travel_Days"]
).round(2)

print(
    site_cost_efficiency[
        [
            "Expense_Per_Day",
            "Total_Travel_Days",
            "Extra_Cost_Per_Day",
            "Potential_Extra_Cost"
        ]
    ].sort_values(
        "Potential_Extra_Cost",
        ascending=False
    )
)
# Out:
# Overall Average Expense Per Travel Day: 3443.15
#                Expense_Per_Day  Total_Travel_Days  Extra_Cost_Per_Day  \
# Site_City
# Mundra                 4292.74                 42              849.59
# Limbdi                 4031.19                 42              588.04
# Surendranagar          3856.49                 49              413.34
# Jamnagar               3960.91                 33              517.76
# Sanand                 3449.16                 62                6.01
# Bhuj                   2769.80                 35             -673.35
# Vadodara               2843.64                 55             -599.51
# Hazira                 2910.44                 78             -532.71
#
#                Potential_Extra_Cost
# Site_City
# Mundra                     35682.78
# Limbdi                     24697.68
# Surendranagar              20253.66
# Jamnagar                   17086.08
# Sanand                       372.62
# Bhuj                      -23567.25
# Vadodara                  -32973.05
# Hazira                    -41551.38

# %%
categories = [
    "Food_Expense",
    "Lodging_Boarding_Expense",
    "Local_Conveyance_Expense",
    "Petrol_Diesel_Expense",
    "NDT_Charges",
    "Other_Expense"
]

site_category_daily = (
    df.groupby("Site_City")[categories].sum()
    .div(df.groupby("Site_City")["Travel_Days"].sum(), axis=0)
)

site_category_daily = site_category_daily.round(2)

print(site_category_daily)
# Out:
#                Food_Expense  Lodging_Boarding_Expense  \
# Site_City
# Bhuj                 424.40                    934.77
# Hazira               328.12                    827.44
# Jamnagar             495.33                   1400.67
# Limbdi               427.52                   1302.50
# Mundra               494.48                   1333.83
# Sanand               368.11                   1106.79
# Surendranagar        469.16                   1125.33
# Vadodara             350.29                   1028.35
#
#                Local_Conveyance_Expense  Petrol_Diesel_Expense  NDT_Charges  \
# Site_City
# Bhuj                             159.20                 328.57       900.00
# Hazira                           179.24                 167.95      1365.38
# Jamnagar                         246.73                 251.52      1484.85
# Limbdi                           271.40                 259.52      1714.29
# Mundra                           357.29                 416.67      1619.05
# Sanand                           313.77                 241.94      1370.97
# Surendranagar                    273.22                 281.63      1663.27
# Vadodara                         217.73                 241.82       963.64
#
#                Other_Expense
# Site_City
# Bhuj                   22.86
# Hazira                 42.31
# Jamnagar               81.82
# Limbdi                 55.95
# Mundra                 71.43
# Sanand                 47.58
# Surendranagar          43.88
# Vadodara               41.82

# %%
category_trip_efficiency = (
    df.groupby("Site_City")
      .agg(
          Number_of_Trips=("Expense_ID", "count"),
          Total_NDT=("NDT_Charges", "sum"),
          Total_Lodging=("Lodging_Boarding_Expense", "sum")
      )
)

category_trip_efficiency["NDT_Per_Trip"] = (
    category_trip_efficiency["Total_NDT"] /
    category_trip_efficiency["Number_of_Trips"]
).round(2)

category_trip_efficiency["Lodging_Per_Trip"] = (
    category_trip_efficiency["Total_Lodging"] /
    category_trip_efficiency["Number_of_Trips"]
).round(2)

print(
    category_trip_efficiency.sort_values(
        "NDT_Per_Trip",
        ascending=False
    )
)
# Out:
#                Number_of_Trips  Total_NDT  Total_Lodging  NDT_Per_Trip  \
# Site_City
# Hazira                      16     106500          64540       6656.25
# Surendranagar               13      81500          55141       6269.23
# Limbdi                      12      72000          54705       6000.00
# Sanand                      16      85000          68621       5312.50
# Mundra                      13      68000          56021       5230.77
# Jamnagar                    10      49000          46222       4900.00
# Vadodara                    12      53000          56559       4416.67
# Bhuj                         8      31500          32717       3937.50
#
#                Lodging_Per_Trip
# Site_City
# Hazira                  4033.75
# Surendranagar           4241.62
# Limbdi                  4558.75
# Sanand                  4288.81
# Mundra                  4309.31
# Jamnagar                4622.20
# Vadodara                4713.25
# Bhuj                    4089.62

# %%
site_category_percentage = (
    df.groupby("Site_City")[
        [
            "Food_Expense",
            "Lodging_Boarding_Expense",
            "Local_Conveyance_Expense",
            "Petrol_Diesel_Expense",
            "NDT_Charges",
            "Other_Expense"
        ]
    ].sum()
)

site_totals = df.groupby("Site_City")["Total_Amount"].sum()

site_category_percentage = (
    site_category_percentage
    .div(site_totals, axis=0)
    .mul(100)
    .round(2)
)

print(site_category_percentage)
# Out:
#                Food_Expense  Lodging_Boarding_Expense  \
# Site_City
# Bhuj                  15.32                     33.75
# Hazira                11.27                     28.43
# Jamnagar              12.51                     35.36
# Limbdi                10.61                     32.31
# Mundra                11.52                     31.07
# Sanand                10.67                     32.09
# Surendranagar         12.17                     29.18
# Vadodara              12.32                     36.16
#
#                Local_Conveyance_Expense  Petrol_Diesel_Expense  NDT_Charges  \
# Site_City
# Bhuj                               5.75                  11.86        32.49
# Hazira                             6.16                   5.77        46.91
# Jamnagar                           6.23                   6.35        37.49
# Limbdi                             6.73                   6.44        42.53
# Mundra                             8.32                   9.71        37.72
# Sanand                             9.10                   7.01        39.75
# Surendranagar                      7.08                   7.30        43.13
# Vadodara                           7.66                   8.50        33.89
#
#                Other_Expense
# Site_City
# Bhuj                    0.83
# Hazira                  1.45
# Jamnagar                2.07
# Limbdi                  1.39
# Mundra                  1.66
# Sanand                  1.38
# Surendranagar           1.14
# Vadodara                1.47

# %%
trip_analysis = df[
    [
        "Expense_ID",
        "Payee_Name",
        "Site_City",
        "Client",
        "Travel_Days",
        "Food_Expense",
        "Lodging_Boarding_Expense",
        "Local_Conveyance_Expense",
        "Petrol_Diesel_Expense",
        "NDT_Charges",
        "Other_Expense",
        "Total_Amount"
    ]
].copy()

trip_analysis["Expense_Per_Day"] = (
    trip_analysis["Total_Amount"] /
    trip_analysis["Travel_Days"]
).round(2)

print(
    trip_analysis.sort_values(
        "Expense_Per_Day",
        ascending=False
    ).head(10)
)
# Out:
#    Expense_ID       Payee_Name      Site_City               Client  \
# 23    TRV1024  Shivam Passwala         Sanand  Gujarat Gas Limited
# 72    TRV1073      Karan Desai  Surendranagar      Larsen & Toubro
# 18    TRV1019     Vishal Joshi         Hazira                 ONGC
# 28    TRV1029      Rahul Patel  Surendranagar      Larsen & Toubro
# 86    TRV1087     Vishal Joshi         Sanand  Gujarat Gas Limited
# 97    TRV1098  Shivam Passwala         Mundra          Adani Group
# 76    TRV1077     Vishal Joshi         Sanand  Gujarat Gas Limited
# 61    TRV1062  Shivam Passwala         Limbdi  Gujarat Gas Limited
# 87    TRV1088     Vishal Joshi       Jamnagar  Reliance Industries
# 63    TRV1064  Shivam Passwala       Jamnagar  Reliance Industries
#
#     Travel_Days  Food_Expense  Lodging_Boarding_Expense  \
# 23            1           802                      5985
# 72            1          1659                      6841
# 18            1           898                      6598
# 28            1          2220                      5732
# 86            1          1180                      6370
# 97            1          1968                      5799
# 76            1          1344                      3267
# 61            2          1528                      6867
# 87            1           794                      3857
# 63            2          2212                      5166
#
#     Local_Conveyance_Expense  Petrol_Diesel_Expense  NDT_Charges  \
# 23                      1176                   1200         9000
# 72                       822                   1500         7000
# 18                      1082                    800         7000
# 28                       518                    800         5000
# 86                      1601                    800         3500
# 97                       871                   1200         3500
# 76                       862                      0         7000
# 61                       698                    800        12000
# 87                       314                    800         5000
# 63                       766                   1500         9000
#
#     Other_Expense  Total_Amount  Expense_Per_Day
# 23              0         18163          18163.0
# 72            100         17922          17922.0
# 18            250         16628          16628.0
# 28            500         14770          14770.0
# 86              0         13451          13451.0
# 97              0         13338          13338.0
# 76            500         12973          12973.0
# 61            500         22393          11196.5
# 87            100         10865          10865.0
# 63            500         19144           9572.0

# %%
Q1 = df["Total_Amount"].quantile(0.25)
Q3 = df["Total_Amount"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)

outliers = df[
    (df["Total_Amount"] < lower_limit) |
    (df["Total_Amount"] > upper_limit)
]

print("\nNumber of Outlier Trips:", len(outliers))

print(
    outliers[
        [
            "Expense_ID",
            "Payee_Name",
            "Site_City",
            "Travel_Days",
            "Total_Amount"
        ]
    ].sort_values(
        "Total_Amount",
        ascending=False
    )
)
# Out:
# Q1: 10431.0
# Q3: 17271.25
# IQR: 6840.25
# Lower Limit: 170.625
# Upper Limit: 27531.625
#
# Number of Outlier Trips: 0
# Empty DataFrame
# Columns: [Expense_ID, Payee_Name, Site_City, Travel_Days, Total_Amount]
# Index: []

# %%
employee_site = (
    df.groupby(["Payee_Name", "Site_City"])["Total_Amount"]
    .agg(
        Total_Expense="sum",
        Number_of_Trips="count",
        Average_Expense="mean"
    )
    .sort_values("Total_Expense", ascending=False)
)

print(employee_site)
# Out:
#                                Total_Expense  Number_of_Trips  Average_Expense
# Payee_Name      Site_City
# Shivam Passwala Mundra                 79345                5     15869.000000
#                 Limbdi                 72126                5     14425.200000
# Vishal Joshi    Sanand                 71788                4     17947.000000
# Amit Shah       Hazira                 71404                5     14280.800000
# Rahul Patel     Surendranagar          69310                5     13862.000000
# Shivam Passwala Sanand                 66559                5     13311.800000
# Vishal Joshi    Bhuj                   57089                5     11417.800000
#                 Vadodara               54375                4     13593.750000
# Rahul Patel     Hazira                 50195                3     16731.666667
# Amit Shah       Mundra                 47713                3     15904.333333
# Karan Desai     Sanand                 47467                4     11866.750000
# Shivam Passwala Surendranagar          46489                3     15496.333333
#                 Hazira                 43594                3     14531.333333
# Karan Desai     Mundra                 42310                4     10577.500000
#                 Surendranagar          41117                3     13705.666667
# Shivam Passwala Vadodara               39689                3     13229.666667
#                 Jamnagar               37358                2     18679.000000
# Vishal Joshi    Limbdi                 36655                3     12218.333333
# Karan Desai     Limbdi                 35200                2     17600.000000
# Vishal Joshi    Hazira                 34474                2     17237.000000
# Karan Desai     Bhuj                   30172                2     15086.000000
# Vishal Joshi    Jamnagar               30092                2     15046.000000
# Amit Shah       Vadodara               29611                3      9870.333333
#                 Sanand                 28034                3      9344.666667
# Karan Desai     Hazira                 27347                3      9115.666667
# Amit Shah       Limbdi                 25329                2     12664.500000
# Rahul Patel     Jamnagar               22656                2     11328.000000
# Karan Desai     Jamnagar               21293                2     10646.500000
# Rahul Patel     Vadodara               19652                1     19652.000000
# Amit Shah       Jamnagar               19311                2      9655.500000
# Vishal Joshi    Surendranagar          18003                1     18003.000000
# Amit Shah       Surendranagar          14049                1     14049.000000
# Karan Desai     Vadodara               13073                1     13073.000000
# Vishal Joshi    Mundra                 10927                1     10927.000000
# Amit Shah       Bhuj                    9682                1      9682.000000

# %%
df["Advance_Utilization_%"] = (
    df["Total_Amount"] / df["Advance_Payment"]
) * 100

print(
    df[
        [
            "Expense_ID",
            "Payee_Name",
            "Advance_Payment",
            "Total_Amount",
            "Balance_Amount",
            "Advance_Utilization_%"
        ]
    ].head(10)
)
# Out:
#   Expense_ID       Payee_Name  Advance_Payment  Total_Amount  Balance_Amount  \
# 0    TRV1001  Shivam Passwala            10278         17708            7430
# 1    TRV1002  Shivam Passwala            10095         13319            3224
# 2    TRV1003      Karan Desai             7566         12586            5020
# 3    TRV1004  Shivam Passwala             8361          7938            -423
# 4    TRV1005  Shivam Passwala            11028         20557            9529
# 5    TRV1006  Shivam Passwala            13407         14684            1277
# 6    TRV1007        Amit Shah             9392         12568            3176
# 7    TRV1008        Amit Shah             6925          6370            -555
# 8    TRV1009     Vishal Joshi            17753         17846              93
# 9    TRV1010      Karan Desai             5035          7567            2532
#
#    Advance_Utilization_%
# 0             172.290329
# 1             131.936602
# 2             166.349458
# 3              94.940797
# 4             186.407327
# 5             109.524875
# 6             133.816014
# 7              91.985560
# 8             100.523855
# 9             150.287984
